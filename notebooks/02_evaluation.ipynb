# %% [markdown]
# # Evaluation de modèles de classification d'avis Steam

# %% [markdown]
# ## Introduction

# %% [markdown]
# Dans ce notebook, nous abordons la prédiction du sentiment des reviews Steam comme un problème de classification binaire.
# L’objectif est de prédire si l’utilisateur recommande le jeu (Recommended) ou non (Not recommended), à partir du commentaire qu'il a laissé sur le site. Le modèle produit permettra de juger de la qualité de la génération de reviews, menée dans la suite de ce projet.

# %% [markdown]
# ## I. Construction des datasets

# %% [markdown]
# Les données ont été récoltées via deux API :
# - https://store.steampowered.com/appreviews/ pour récolter les reviews des joueurs
# - https://store.steampowered.com/api/appdetails/ pour récolter des informations sur les jeux.
#
# 10 jeux ont été considérés pour l'entraînement des modèles. Afin de garantir une présence suffisante d'avis négatifs, certains jeux réputés comme décevant par les joueurs ont été choisi. Le jeux sont :
# - Dota 2
# - Counter-Strike 2
# - Team Fortress 2
# - Cyberpunk 2077
# - Elden Ring
# - Battlefield 2042
# - The Day Before
# - Overwatch 2
# - Payday 3
# - GTA Trilogy Definitive Edition
#
#
# 4 jeux ont été choisis pour évaluer les performances des modèles de classification :
# - Deep Rock Galactic
# - Valheim
# - Halo Infinite
# - Redfall
#
#
# Les reviews sont ensuite triées afin de ne garder que des reviews récentes, en anglais, avec un nombre de caractères suffisant.
#
# Les dataset finaux sont déséquilibrés :
# - 33% de reviews "Not Recommended" pour le jeu de données d'entraînement
# - 25% de reviews "Not Recommended" pour le jeu de validation

# %% [markdown]
# ## II. Modélisations

# %% [markdown]
# Les données (textes des reviews) ne pouvant pas être traitées directement par des algorithmes de machine learning, elles sont transformées en représentations numériques à l’aide de deux méthodes, qui pourront être comparées :
# - la méthode **TF-IDF** (Term Frequency - Inverse Document Frequency) : approche qui attribue à chaque mot un poids proportionnel à sa fréquence dans un document, tout en pénalisant les termes trop fréquents dans l’ensemble du corpus. Les mots les plus informatifs — fréquents dans un avis mais rares globalement — reçoivent ainsi un poids plus élevé, permettant au modèle de capturer efficacement le signal de sentiment présent dans le texte. Ici, le modèle peut utiliser des unigrammes (1 mot) ou des bigrammes (2 mots), ce qui permet de capter des expressions figées ou des négations simples.
# - La méthode **SBERT** (Sentence-BERT) repose sur l’utilisation de modèles de langage pré-entraînés de type Transformer afin de produire des représentations vectorielles denses de phrases ou de textes entiers. L'intérêt de cette approche est qu'elle encode un texte en prenant en compte le contexte global et l'ordre des mots, donc de capturer le sens sémantique de de la review.

# %% [markdown]
# Après avoir testé plusieurs modèles, deux classifieurs ont été retenus, basés sur un classifieur SVM : `LinearSVC(class_weight="balanced", max_iter=5000, random_state=42)`
#
# Le premier repose sur le classifieur SVM entraîné sur des représentations vectorielles TF-IDF des reviews. La seconde utilise un SVM entraîné sur des embeddings sémantiques de reviews obtenus à l’aide de SBERT.

# %% [markdown]
# ## III. Analyse des modèles

# %% [markdown]
# Dans cette partie, nous analysons en détail les **erreurs de classification** produites par ces deux modèles.
# L’objectif est de **comprendre les limites intrinsèques des deux modèles de classification des reviews**, en identifiant les cas où leurs prédictions sont incorrectes.
#
# Cette analyse vise à répondre aux questions suivantes :
# - quels mots influencent le plus le modèle pour la classification "Recommended"/"Not Recommended" ?
# - quels types de reviews sont mal classés ? Pourquoi ?
# - quel modèle semble être le meilleur ?

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent  
sys.path.append(str(PROJECT_ROOT))

# %%
import pandas as pd
import numpy as np
import joblib
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score, confusion_matrix, classification_report
from src.utils import SBERTEmbedder

# %%
# Paths
DATA_PATH = "../data/processed/dataset_val.csv"
PATH_TFIDF = "../reports/models/judge_model_tfidf.joblib"
PATH_SBERT = "../reports/models/judge_model_sbert.joblib"


# Load data
df = pd.read_csv(DATA_PATH)
df["review_text"] = df["review_text"].fillna("").astype(str)

# Filter short reviews
df = df[df["review_text"].str.len() >= 30].copy()

X = df["review_text"]
df["recommended"] = (df["rating"] == 9).astype(int)
y = df["recommended"].astype(int)

# %% [markdown]
# # III.1. Modèle issu de TF-IDF

# %%
# Trained model
model_t = joblib.load(PATH_TFIDF)
tfidf = model_t.named_steps["tfidf"]
clf = model_t.named_steps["clf"]
feature_names_t = tfidf.get_feature_names_out()

coefs_t = clf.coef_[0]
y_pred_t = model_t.predict(X)
scores_t = model_t.decision_function(X)

# %% [markdown]
# Performances du modèle

# %%
# ROC-AUC
roc_auc = roc_auc_score(y, scores_t)

# Matrice de confusion
cm = confusion_matrix(y, y_pred_t)

print(f"ROC-AUC: {roc_auc:.4f}")
print("Confusion matrix:\n", cm)
print(classification_report(y, y_pred_t, digits=4))
# Out:
# ROC-AUC: 0.9147
# Confusion matrix:
#  [[ 789  296]
#  [ 384 3687]]
#               precision    recall  f1-score   support
#
#            0     0.6726    0.7272    0.6988      1085
#            1     0.9257    0.9057    0.9156      4071
#
#     accuracy                         0.8681      5156
#    macro avg     0.7992    0.8164    0.8072      5156
# weighted avg     0.8724    0.8681    0.8700      5156

# %%
# Inspect features with highest positive and negative coefficients 
top_pos = np.argsort(coefs_t)[-20:]
top_neg = np.argsort(coefs_t)[:20]

print("\nTop POSITIVE features:")
for i in top_pos[::-1]:
    print(feature_names_t[i], coefs_t[i])

print("\nTop NEGATIVE features:")
for i in top_neg:
    print(feature_names_t[i], coefs_t[i])
# Out:
# Top POSITIVE features:
# best 2.6666596362431823
# good 2.294426723699297
# love 2.2467801865827375
# not bad 2.160727942905289
# great 2.1011735884587392
# fun 2.0937880226054575
# peak 2.0407510459382174
# awesome 1.861391647917958
# perfect 1.8002735060190016
# amazing 1.790596862256118
# bit 1.676468770832323
# игра 1.5168740523157287
# would recommend 1.474729745013814
# masterpiece 1.4729310540132867
# funny 1.4682909281036904
# enjoyable 1.4221278662826655
# you don 1.3515584419255122
# cyberpunk 1.3438915393004858
# 10 10 1.3231871565148183
# that bad 1.3070837595697005
#
# Top NEGATIVE features:
# worst -2.2794507564197057
# garbage -2.2241711935087545
# boring -2.215877049539426
# crashing -2.1625142660791448
# shit -2.115481640562072
# terrible -2.0988376420711568
# sucks -1.993400957004268
# the worst -1.9729905052862922
# trash -1.9542086780007253
# no -1.9474206752887606
# not worth -1.9463414342825223
# worse -1.9098086051174856
# refund -1.8985636430741017
# job -1.864995627111468
# even -1.803776379003054
# ea -1.7788512297166958
# not -1.7781069648676153
# money -1.7209197396644091
# disappointment -1.6917597532911084
# do not -1.6561671911903462

# %% [markdown]
# Pour les reviews classées "Recommended" :
# Les tokens ayant le plus gros poids pour classer en "Recommended" sont des mots  à connotation positives : "best", "good", "love" etc...
# Pour les reviews classées "Not Recommended" :
# Les tokens ayant le plus de poids pour classer en "Not Recommended" sont des mots négatifs : "worst", "garbage", "boring"

# %%
# Index TP / FP / TN / FN
idx_tp = np.where((y == 1) & (y_pred_t == 1))[0]
idx_fp = np.where((y == 0) & (y_pred_t == 1))[0]
idx_tn = np.where((y == 0) & (y_pred_t == 0))[0]
idx_fn = np.where((y == 1) & (y_pred_t == 0))[0]

print("TP:", len(idx_tp))
print("FP:", len(idx_fp))
print("TN:", len(idx_tn))
print("FN:", len(idx_fn))
# Out:
# TP: 3687
# FP: 296
# TN: 789
# FN: 384

# %%
# Discriminant contribution function
def discriminant_table(X, indices, label, top_n=10):
    X_sub = X.iloc[indices]
    X_vec = tfidf.transform(X_sub)
    contrib = X_vec.multiply(coefs_t).sum(axis=0).A1
    top_idx = np.argsort(np.abs(contrib))[::-1][:top_n]
    return pd.DataFrame({
        "word": feature_names_t[top_idx],
        f"contribution_{label}": contrib[top_idx]
    })

tp = discriminant_table(X, idx_tp, "TP")
fp = discriminant_table(X, idx_fp, "FP")
tn = discriminant_table(X, idx_tn, "TN")
fn = discriminant_table(X, idx_fn, "FN")

# %%
# Comparisons

tp_fp = tp.merge(fp, on="word", how="outer").fillna(0)
tn_fn = tn.merge(fn, on="word", how="outer").fillna(0)

# Sort by correct decision contribution

tp_fp = tp_fp.sort_values("contribution_TP", ascending=False).reset_index(drop=True)
tn_fn = tn_fn.assign(abs_TN=lambda x: x.contribution_TN.abs()) \
               .sort_values("abs_TN", ascending=False) \
               .drop(columns="abs_TN") \
               .reset_index(drop=True)


print("\nTop TP vs FP words (sorted by TP):")
print(tp_fp.head(10))

print("\nTop TN vs FN words (sorted by |TN|):")
print(tn_fn.head(10))
# Out:
# Top TP vs FP words (sorted by TP):
#     word  contribution_TP  contribution_FP
# 0    fun       158.499804         7.759838
# 1   good       153.476748         8.277212
# 2  great       141.574053         4.952031
# 3   best       125.396447         0.000000
# 4   love       115.580256         0.000000
# 5    but        88.084598         9.046567
# 6     10        74.395638         0.000000
# 7   just         0.000000        -5.854228
# 8    not         0.000000       -10.505476
# 9     of         0.000000        -5.188901
#
# Top TN vs FN words (sorted by |TN|):
#      word  contribution_TN  contribution_FN
# 0     not       -39.529405       -13.262628
# 1      to       -34.136478       -14.107565
# 2      is       -28.772900       -12.041848
# 3      no       -24.462089        -8.488990
# 4    this       -23.659212        -9.486585
# 5    just       -23.275094        -8.118139
# 6     but        21.905132         9.577045
# 7    they       -20.267180        -7.446277
# 8  boring       -19.309725         0.000000
# 9      of       -19.132067        -7.836831

# %%
print("Contribution des mots aux faux positifs et faux négatifs")
print("Faux positifs :")
print(fp.head(15))

print("Faux négatifs :")
print(fn.head(15))
# Out:
# Contribution des mots aux faux positifs et faux négatifs
# Faux positifs :
#     word  contribution_FP
# 0    not       -10.505476
# 1    but         9.046567
# 2     to        -8.579437
# 3   good         8.277212
# 4     is        -8.055618
# 5    fun         7.759838
# 6   this        -6.355578
# 7   just        -5.854228
# 8     of        -5.188901
# 9  great         4.952031
# Faux négatifs :
#       word  contribution_FN
# 0       to       -14.107565
# 1      not       -13.262628
# 2       is       -12.041848
# 3      but         9.577045
# 4     this        -9.486585
# 5       no        -8.488990
# 6     just        -8.118139
# 7  dungeon        -8.035479
# 8       of        -7.836831
# 9     they        -7.446277

# %%
# Coefficients of the linear SVM
coef_df = pd.DataFrame({
    "word": feature_names_t,
    "coef": coefs_t
})

# Selection
top_pos = coef_df.sort_values("coef", ascending=False).head(10)
top_neg = coef_df.sort_values("coef", ascending=True).head(10)

top_pos = top_pos.sort_values("coef", ascending=True)

# Concatenation
top = pd.concat([top_neg, top_pos])

# Plot
plt.figure(figsize=(8, 6))
plt.barh(top["word"], top["coef"])
plt.axvline(0, color="black")
plt.title("Global feature importance (Linear SVM)")
plt.xlabel("Coefficient value")
plt.tight_layout()
plt.show()

# %%
# Words contributing most to False Positives
fp_words = discriminant_table(X, idx_fp, "FP", top_n=50)

# Only positive contributions
fp_words = (
    fp_words[fp_words["contribution_FP"] > 0] # Words pushing to positive class
    .sort_values("contribution_FP", ascending=False)
    .head(10)
)

plt.figure(figsize=(6, 4))
plt.barh(fp_words["word"], fp_words["contribution_FP"])
plt.gca().invert_yaxis()  # Invert y-axis to have the highest on top
plt.title("Words contributing most to False Positives")
plt.xlabel("Contribution to positive class")
plt.tight_layout()
plt.show()

# %% [markdown]
# Les faux positifs sont principalement causés par la présence de mots à connotation positive isolés, tels que "good", "fun" ou "great", qui suffisent à faire basculer la prédiction vers la classe positive malgré un avis globalement négatif.
#
# Le classifieur TF-IDF accorde un poids important à des marqueurs discursifs comme "but", qu’il associe à tort à une polarité positive en raison de leur cooccurrence fréquente avec des expressions positives.

# %%
tp_words = discriminant_table(X, idx_tp, "TP", top_n=10)

display(fp_words)
display(tp_words)
# Out:
#      word  contribution_FP
# 1     but         9.046567
# 3    good         8.277212
# 5     fun         7.759838
# 9   great         4.952031
# 12    and         4.267568
# 13   love         4.025134
# 14   best         3.796230
# 16     my         3.539909
# 17  first         3.435330
# 19     it         3.097215
#     word  contribution_TP
# 0    fun       158.499804
# 1   good       153.476748
# 2  great       141.574053
# 3   best       125.396447
# 4   love       115.580256
# 5     is       -92.821715
# 6    but        88.084598
# 7     to       -86.200586
# 8     10        74.395638
# 9   this       -72.085666

# %%
# Words contributing most to False Positives
fn_words = discriminant_table(X, idx_fp, "FN", top_n=50)

# Only negative contributions
fn_words = (
    fn_words[fn_words["contribution_FN"] < 0] # Words pushing to negative class
    .sort_values("contribution_FN", ascending=False)
    .head(10)
)

plt.figure(figsize=(6, 4))
plt.barh(fn_words["word"], fn_words["contribution_FN"])
plt.title("Words contributing most to False Negatives")
plt.xlabel("Contribution to negative class")
plt.tight_layout()
plt.show()

# %% [markdown]
# Les faux négatifs sont majoritairement associés à des mots fonctionnels ou contextuels ("that", "too", "only", "then"), révélant que le modèle confond complexité linguistique et négativité.
#
# Les avis positifs exprimant des nuances ou des concessions sont pénalisés par le classifieur TF-IDF, qui assimile la présence d’arguments ou de descriptions techniques à une critique négative. Le modèle tend ainsi à sous-estimer les avis positifs riches et argumentés, au profit d’avis courts et lexicalement explicites.

# %% [markdown]
# ## III. Modèle issu de SBERT

# %% [markdown]
# Contrairement au modèle précédent, les classifieurs basés sur un embedding SBERT ne permettent pas une interprétation basée sur les mots, dans la mesure où les features correspondent à la sémantique de la review. C'est pourquoi l'analyse sera faite au niveau de la review.

# %%
# Trained model
model_s = joblib.load(PATH_SBERT)

embedder = model_s.named_steps["embed"]
clf = model_s.named_steps["clf"]

y_pred_s = model_s.predict(X)
scores_s = model_s.decision_function(X)
# Out:
# Batches: 100%|██████████| 162/162 [00:48<00:00,  3.31it/s]
# Batches: 100%|██████████| 162/162 [00:49<00:00,  3.25it/s]

# %%
# ROC-AUC
roc_auc = roc_auc_score(y, scores_s)

# Matrice de confusion
cm = confusion_matrix(y, y_pred_s)

print(f"ROC-AUC: {roc_auc:.4f}")
print("Confusion matrix:\n", cm)
print(classification_report(y, y_pred_s, digits=4))
# Out:
# ROC-AUC: 0.9015
# Confusion matrix:
#  [[ 892  193]
#  [ 781 3290]]
#               precision    recall  f1-score   support
#
#            0     0.5332    0.8221    0.6468      1085
#            1     0.9446    0.8082    0.8711      4071
#
#     accuracy                         0.8111      5156
#    macro avg     0.7389    0.8151    0.7590      5156
# weighted avg     0.8580    0.8111    0.8239      5156

# %%
tp_s = (y == 1) & (y_pred_s == 1)
fp_s = (y == 0) & (y_pred_s == 1)
tn_s = (y == 0) & (y_pred_s == 0)
fn_s = (y == 1) & (y_pred_s == 0)

# %%
plt.figure(figsize=(8, 5))

plt.hist(scores_s[tp_s], bins=30, alpha=0.5, label="TP")
plt.hist(scores_s[fp_s], bins=30, alpha=0.5, label="FP")
plt.hist(scores_s[fn_s], bins=30, alpha=0.5, label="FN")
plt.hist(scores_s[tn_s], bins=30, alpha=0.5, label="TN")

plt.xlabel("Decision score (distance to SVM hyperplane)")
plt.ylabel("Number of reviews")
plt.title("Distribution of SBERT-SVM decision scores by prediction outcome")

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# The score distribution highlights a clear separation between positive and negative reviews. False positives and false negatives are mostly located near the decision boundary, suggesting that misclassifications are driven by nuanced or mixed opinions rather than by systematic weaknesses of the classifier.

# %%
idx_fp_s = np.where((y == 0) & (y_pred_s == 1))[0]
idx_fn_s = np.where((y == 1) & (y_pred_s == 0))[0]
df.iloc[idx_fp_s[:10]][["review_text"]]
df.iloc[idx_fn_s[:10]][["review_text"]]
# Out:
#                                            review_text
# 1    Gameplay is extremely repetitive and adds char...
# 23   Fun with friends for the first few days, then ...
# 53   I'm only down thumbing because Steam does offe...
# 80        Wasn't my thing. Rather just play Helldivers
# 137  I really enjoy the game... but had to uninstal...
# 155  really boring not that fun ngl even my friend ...
# 245  I really want to like this game, and I keep tr...
# 259  fr one of the worst games ive ever played and ...
# 263  Its a no from me dawg. As shallow as sea of th...
# 271  nearly every time i do a pipline mission i get...

# %%
for i in idx_fp_s[:10]:
    print("—" * 80)
    print(df.loc[i, "review_text"])
# Out:
# ————————————————————————————————————————————————————————————————————————————————
# Gameplay is extremely repetitive and adds characters that use they/them pronouns.
# ————————————————————————————————————————————————————————————————————————————————
# Fun with friends for the first few days, then the gameplay gets really boring, and repetitive. Like the free stuff they give but that is the only good thing I can think about this game, I would rather hangout in a Discord VC with friends playing nothing than play this game.
# ————————————————————————————————————————————————————————————————————————————————
# I'm only down thumbing because Steam does offer an option in between.
#
# This is a first person shooting miner style game where you drop in for missions and once complete you leave to return to a main hub. You have a few classes to choose from; all with their own weapons and gadgets. Your objective; go down and mine some resources to a certain amount or complete an objective. As you do; you deal with hordes of insect like creatures that make the planet their home. Differences in creatures is what you'd expect from a game like this. Some armored, some elemental, some bigger or smaller, etc.
#
# This is a veeeery simple game. Think of this as more of something that came out on PS2 if any of you remember that era. It's very basic as far as complexity goes since every map is procedurally generated and the Hub is very small. Exploration is sometimes rewarded but usually it's only a couple secrets that will ping when close by. Very easy for anyone to pick up even if they are new to this type of game.
#
# What drew me? The mining. I'm a biggggg mining buff and being able to dig and mine resources scratches that itch for me. I like shiny things; what can I say?
#
# What I liked? I like the bar. I like the robots and the fun nature of the dwarves interacting with each other. I'm a big fan of machinery too so the drillship and all the big equipment feels fun and exciting. Like I said earlier; I love the mining. Gunplay isn't too bad either and it feels good wiping out hordes of bugs.
#
# Why a thumb down? It's not really a thumb down. More like a thumb sideways. There just isn't anything worth obtaining. There are no goals. Nothing endgame is worth wanting to keep playing except for the fact of playing itself. You'll end up maxing out characters and weapons. Then you get to the higher level missions. Then you get all the cosmetics. Then there is nothing left. You did it all. There are no extra weapons you get or unlock. No new skills. No way to upgrade hub or anything to use excess resources on. It's almost as if they expected people to just stop playing it once they "beat" it despite the fact they are always releasing cosmetics as if it's a live service type of game. Even a live service game typically adds content to drag out endgame and even usually have an endgame.
#
# Final Review: 5/10
#
# +1 for theme                                                                    -1 For no endgame
# +1 for atmosphere                                                           -1 For focusing cosmetics
# +1 for mining                                                                    -1 For lack of hub freedom
# +1 for gunplay with hordes                                                -1 For no extra weapons/gadgets
# +1 for good team play                                                       -1 For moving on despite releasing cosmetics
#
# A very good simple game but if you want something a little deeper; you may keep looking.
# ————————————————————————————————————————————————————————————————————————————————
# Wasn't my thing. Rather just play Helldivers
# ————————————————————————————————————————————————————————————————————————————————
# I really enjoy the game... but had to uninstall coz there are too many disconnects that spoil ur game and u can not get back and re join.
# ————————————————————————————————————————————————————————————————————————————————
# really boring not that fun ngl even my friend agreed 4/10
# ————————————————————————————————————————————————————————————————————————————————
# I really want to like this game, and I keep trying to, first on PS4 then on PC. The problem is, I only play solo, and the game is REALLY bad for that. If you want to play coop with some friends I can see how this might be fun, but solo it's just a tedious slog and not worth your time at all. The biggest problem is the procedurally generated maps. There's a lot of verticality, and it's really hard to get around by yourself in some of the large caverns, as well as just finding the minerals you need to complete the mission.
#
# They aren't that abundant, and you end up just running in circles in the dark trying to find where the last deposit or two is, because it seems like you basically need to find all of these randomly located deposits to have enough to win, or close to it. And waves of enemies keep attacking in combat that isn't really fun or challenging, but just eats your ammo until you run out and run out of resupply pods.
#
# Then you die and get basically nothing after spending an hour wandering around because you didn't notice some random mineral deposit on the top left upper bit of one of ten caverns that are so dark you can't see anything anyway.
#
# I'm sure you could put the time in and learn how the procedural generation works and where it's more likely to put deposits and caves, but the in-game map is so abstract as to be nearly useless, and when learning the game isn't even remotely fun, I don't see why I should bother.
#
# Basically, if you've got some friends, go for it, but don't bother if you're planning on playing solo. It's a complete waste of your time.
# ————————————————————————————————————————————————————————————————————————————————
# fr one of the worst games ive ever played and is so unfun
# ————————————————————————————————————————————————————————————————————————————————
# Its a no from me dawg. As shallow as sea of thieves. There is no sense of progression.
# ————————————————————————————————————————————————————————————————————————————————
# nearly every time i do a pipline mission i get stuck in a pipe unable to move  so i have to quite the mission

# %%
for i in idx_fn_s[:10]:
    print("—" * 80)
    print(df.loc[i, "review_text"])
# Out:
# ————————————————————————————————————————————————————————————————————————————————
# finaly my v key gets as much usage as WASD.
#
# ROCK AND STONE
# ————————————————————————————————————————————————————————————————————————————————
# One of the best games to ever grace Steam.
#
# Play this game, you dumb bastard.
# ————————————————————————————————————————————————————————————————————————————————
# Прекрасная кооп игра. Если не считать того что происходит на 4-5+ хазардах, то я думаю ее можно назвать расслабляющей? Не жалею не единого рубля потраченного на эту игру
# ————————————————————————————————————————————————————————————————————————————————
# why wouldnt you play this 10/10 best coop game ever
# ————————————————————————————————————————————————————————————————————————————————
# Quick review: 5
#
# ### Metric ###
# 1- Garbage. :(
# 2- Did not fulfill the purpose.
# 3 - Ok, fulfilled the purpose.
# 4 - A good game!
# 5 - Just play and be happy. :)
# ————————————————————————————————————————————————————————————————————————————————
# After well over 1000 hours I am still finding more nuance and intereting new gun builds in this game. Love every bit of it, shooter gameplay is deep and complex between the weapon upgrades and ocerclocks, hide and seek, soccer, and jetty boot minigames, incredible mission modifiers and events, a 100% FREE battlepass in the face of mtx everywhere, still heartpounding and  novel situations, fantastic team play if you take the time to learn it, varied enemies each with unique sounds so you can identify them from rooms away, . The only things you can pay for are a few themed cosmetic packs, but there are hundreds of free cosmetics that you earn—quite quickly—just by playing the game. There is zero gameplay behind a paywall after you buy the game. I am so excited for the next game, and idk if deep rock galactic will every leave my regularly played games. Highly recommend the tweak the intern, fancy molly, more players balanced, and flashlight rangex2 mods.
#
# Rock and Stone!
# ————————————————————————————————————————————————————————————————————————————————
# if you're a long time player of the DRG this FPS version is gonna tickle your inner dwarf.
# ————————————————————————————————————————————————————————————————————————————————
# perty shit my team amte sucked small dick so it was quite hard
#
# ————————————————————————————————————————————————————————————————————————————————
# my friend accidentally split reality in half and a bunch of giant space bugs ate us.
#
# 10/10 would reccommend
# ————————————————————————————————————————————————————————————————————————————————
# Easily one of my favorite four player PvE games of all time, DRG is filled to the brim with character, style, and endless replay ability. There are many other PvE horde fighting games, but where else can you play as a dwarf throwing back drinks and ass at a bar in a space rig before mining down into the depths of bug ridden hell? Speaking of throwing it back with your homies, the vast majority of the community is, from my personal experience, friendly and helpful with veteran players having no issues when welcoming new players and sharing tips for all the different missions and special events. The community also has a ridiculous hive mind of inside-game jokes and culture such as "Rock and stoning" fellow dwarfs in missions or spamming the callout button of large chunks of gold shouting "We're rich" to the point management has to comment on us getting back to work.
#
# With four classes to play as you get to experience a variety of unique play styles with each also offering different weapons and upgrades to allow for even more tweaks to your experience. But plenty of other games in this genre have multiple classes to choose from, so what makes this game stand out? For me the biggest part of what separates this game’s gameplay from its competitors is that each cave is randomly generated. I am used to and enjoy grinding out these sorts of games and can admire great level designs, and while those other games offer a familiarity in their levels that is helpful in speeding through missions, I personally feel those can become stale over time and boredom has a higher chance of setting in. In DRG, I can play the same mission type multiple times in a row with no two caves being the exact same, even in the same biomes. This, on top of the already addicting gameplay of clearing hordes of bugs and grinding for new weapon overclocks and cosmetics is what keeps the game fresh for me and has me continuing coming back for more.

# %%
# Scores des faux positifs
fp_scores = scores_s[idx_fp_s]

# Indices des 5 faux positifs les plus confiants
top_fp_idx = idx_fp_s[np.argsort(fp_scores)[::-1][:5]]

# Affichage texte lisible
for i in top_fp_idx:
    print(f"SCORE = {scores_s[i]:.3f}")
    print(df.iloc[i]["review_text"])
    print("-" * 100)
# Out:
# SCORE = 2.339
# Great game, even better with friends!
# ----------------------------------------------------------------------------------------------------
# SCORE = 1.556
# Beautiful game and runs well. I like it a lot.  Just be careful not to change chapters and over write your saved like I did.  The game will warn you if you are about to overwrite them.  There are some bug where there are places in the game where it is impossible to progress through. I DO REALLY LIKE THIS GAME.  It has multiplayer option also which is a lot of fun to play.
# ----------------------------------------------------------------------------------------------------
# SCORE = 1.431
# Very cool final boss! I love the epic FACE YOUR FAILURES ability that gives no information, then summons a special, unique ghost to fight! It's very cool when they spring this move on you with no information, your supports can't damage it, and you lose the run! Thank you so much!
# ----------------------------------------------------------------------------------------------------
# SCORE = 1.139
# Im gonna lie, this game is amazing 🔥🔥🔥
# ----------------------------------------------------------------------------------------------------
# SCORE = 1.010
# No México Banner.
#
# In story mode I feel like a BETA tester, so many bugs in my first run. It's funny for me but maybe not for others.
#
# \Player one is a triger for certain events in the campaing, it wasn't made for more than one player. Good Horde mode.
# ----------------------------------------------------------------------------------------------------

# %%
# Scores des faux négatifs
fn_scores = scores_s[idx_fn_s]

# Indices des 5 faux négatifs les plus confiants
top_fn_idx = idx_fn_s[np.argsort(fn_scores)[:5]]

# Affichage texte lisible
for i in top_fn_idx:
    print(f"SCORE = {scores_s[i]:.3f}")
    print(df.iloc[i]["review_text"])
    print("-" * 100)
# Out:
# SCORE = -1.494
# zero microtransactions the amount of free content they pump out is insane
# ----------------------------------------------------------------------------------------------------
# SCORE = -1.462
# They knocked it out of the park with this one but they need start penalizing players for quitting mid-game on multiplayer because it's getting ridiculous.
# ----------------------------------------------------------------------------------------------------
# SCORE = -1.317
# The game runs smoothly except for the problem below.
#
# In Linux it was a huge pain to log in because the in-game browser sucks and didn't read my keyboard before some workarounds. They could do like the other publishers and simply put the log in screen outside of the game.
# ----------------------------------------------------------------------------------------------------
# SCORE = -1.298
# To be fair, I would've give this game a "Not Recommended" by the time in September 2019, if you guys remember Gears 5 have a rough launch and was buggy in multiplayer. Unfortunately, I was unable to do so because of Xbox Live Gold ran out on my Xbox One (which it was at the time before Series X/S), lack of enjoyment after the campaign.
#
# The campaign was solid but not perfect, even as a veteran Gears of War fan. I love playing the multiplayer and has been improved since the game first came out in 2019.
# ----------------------------------------------------------------------------------------------------
# SCORE = -1.284
# Beware of the time-sink anomaly when booting up this game. I'm pretty sure Odin has something to do with this...
# ----------------------------------------------------------------------------------------------------
