# %%
from google.colab import drive
drive.mount("/content/drive")

# !find "/content/drive" -maxdepth 6 -name "adapter_config.json" -print
# Out:
# Mounted at /content/drive

# %%
# !find "/content/drive" -maxdepth 8 -name "adapter_config.json" -print
# Out:
# /content/drive/.shortcut-targets-by-id/14ok9jUkxn5Ww4SgxFGRMgEXs78uQROae/steam_project_lora/steam_lora_adapter/adapter_config.json
# find: ‘/content/drive/.Encrypted/.shortcut-targets-by-id/14ok9jUkxn5Ww4SgxFGRMgEXs78uQROae/steam_project_lora’: No such file or directory

# %%
# !ls -la "/content/drive/MyDrive"
# !ls -la "/content/drive/MyDrive" | head
# Out:
# total 826731
# -rw-------  1 root root  5844875 Jul  7 14:35  20250618_154133.jpg
# drwx------  2 root root     4096 Dec 15  2022 'anglais proba'
# -rw-------  1 root root      175 Jun  5  2025 'appel guillaume gaudron.gdoc'
# drwx------  2 root root     4096 Nov 22  2021  bleu
# drwx------  3 root root     4096 Jul  4  2024  Borderlands-Sensitivity-Changer-main
# -rw-------  1 root root      175 Nov 11 11:05  Bouquins.gdoc
# -rw-------  1 root root      175 Mar  2  2020 'Ces idées qui collent.gslides'
# -rw-------  1 root root      175 Mar 12  2021 'chaine mentale tipe.gdoc'
# -rw-------  1 root root      175 Feb 14  2024 'Chapitre_9-1 (1).gdoc'
# -rw-------  1 root root      175 Feb 14  2024  Chapitre_9-1.gdoc
# -rw-------  1 root root      175 Feb 18  2024 'Chapitre_9 (1).gdoc'
# -rw-------  1 root root      175 Feb 18  2024 'Chapitre_9 (2).gdoc'
# -rw-------  1 root root      175 Feb 14  2024 'Chapitre_9 (3).gdoc'
# -rw-------  1 root root      175 Feb 14  2024 'Chapitre_9 (4).gdoc'
# -rw-------  1 root root      175 Feb 18  2024  Chapitre_9.gdoc
# -rw-------  1 root root      175 Jan 17  2024  Chapitres_1_2_et_3.gdoc
# -rw-------  1 root root      175 May  4  2025  CHESS.gdoc
# drwx------  2 root root     4096 Jul 18  2024 'Colab Notebooks'
# -rw-------  1 root root      175 Mar 24  2020 'COURS SPH 24 MARS 2020.gdoc'
# -rw-------  1 root root      175 Jun 20  2021  croatie.gdoc
# -rw-------  1 root root      175 Feb 10  2020 'Document sans titre (10).gdoc'
# -rw-------  1 root root      175 Jan 29  2020 'Document sans titre (11).gdoc'
# -rw-------  1 root root      175 Jan 28  2020 'Document sans titre (12).gdoc'
# -rw-------  1 root root      175 Jan 13  2020 'Document sans titre (13).gdoc'
# -rw-------  1 root root      175 Mar 21  2025 'Document sans titre (1).gdoc'
# -rw-------  1 root root      175 Mar 16  2025 'Document sans titre (2).gdoc'
# -rw-------  1 root root      175 May 12  2024 'Document sans titre (3).gdoc'
# -rw-------  1 root root      175 Dec 12  2022 'Document sans titre (4).gdoc'
# -rw-------  1 root root      175 Dec 12  2022 'Document sans titre (5).gdoc'
# -rw-------  1 root root      175 Dec 11  2022 'Document sans titre (6).gdoc'
# -rw-------  1 root root      175 Oct 28  2021 'Document sans titre (7).gdoc'
# -rw-------  1 root root      175 Apr 10  2020 'Document sans titre (8).gdoc'
# -rw-------  1 root root      175 Mar 10  2020 'Document sans titre (9).gdoc'
# -rw-------  1 root root      175 Mar 27  2025 'Document sans titre.gdoc'
# -rw-------  1 root root      175 Feb 13  2025 'Document sans titre - Graphique à secteurs 1.gsheet'
# -rw-------  1 root root   224051 Jul 20 17:18  E-billet_copie.pdf
# -rw-------  1 root root      175 Mar 12  2021 "Elaboration d'un capteur d'obstacle .gdoc"
# drwx------  6 root root     4096 Aug  2 13:54 'ENSAE été'
# -rw-------  1 root root      175 Nov 25 12:13 'entreprises stage.gdoc'
# -rw-------  1 root root      175 Nov 27 13:29 'entretien BRAIN AND MINDS.gdoc'
# -rw-------  1 root root      175 Nov 27 17:12 'entretien thales.gdoc'
# -rw-------  1 root root      175 May  1  2019 'espagnol (1).gdoc'
# -rw-------  1 root root      175 Mar 24  2020  espagnol.gdoc
# -rw-------  1 root root      175 Jun 25  2019 'Extra 14.gdoc'
# -rw-------  1 root root      175 Jun 26  2019 'Extra 15.gdoc'
# -rw-------  1 root root    79911 Aug 15 18:04  F-2.1-2-enigmes_copie.pdf
# -rw-------  1 root root      175 Dec  6 13:59  FREEPLAY.gdoc
# -rw-------  1 root root      175 Apr 27  2021  fr.gdoc
# -rw-------  1 root root      175 Jul 13 19:03  GAMING.gdoc
# -rw-------  1 root root      175 Jun 20  2021 'Groupe Mathieu Lise :.gdoc'
# -rw-------  1 root root      175 May 12  2025  hz_liste_agreg2024.gsheet
# -rw-------  1 root root      175 Jul 14 22:38 'Idées projet.gdoc'
# -rw-------  1 root root      175 Jun  1  2024 'Idées vidéos .gdoc'
# -rw-------  1 root root      175 Feb 13  2025  jm.gdoc
# -rw-------  1 root root      175 Jun 13  2025 'leçons dévs faites ou pas.gsheet'
# -rw-------  1 root root      175 Aug 28  2024 'Lettre de Motivation Mathieu Lang Pré-Accord Collégial.gdoc'
# -rw-------  1 root root      175 Nov 11 11:11 'Manga anime.gdoc'
# -rw-------  1 root root      175 Feb 12  2025 'mathieu lang (avec un seul t hein alex).gslides'
# -rw-------  1 root root      175 Apr 20  2025 'musique de fond vidéo etc.gdoc'
# -rw-------  1 root root      175 May 31  2024 'Notes (1).gsheet'
# -rw-------  1 root root      175 Jan 19  2024 'NotesAlgebre (1).gsheet'
# -rw-------  1 root root      175 Jan 19  2024 'NotesAlgebre (2).gsheet'
# -rw-------  1 root root      175 May  5  2024  NotesAlgebre.gsheet
# -rw-------  1 root root      175 May 31  2024  Notes.gsheet
# -rw-------  1 root root      175 Feb 21  2024 'océ sciences.gdoc'
# drwx------ 10 root root     4096 Jun 30  2024  PC
# -rw-------  1 root root      175 Nov 13 16:02  piano.gdoc
# -rw-------  1 root root      175 Nov 14  2024 'pré accord collégial.gdoc'
# -rw-------  1 root root      175 Dec 16 21:48 'Présentation sans titre.gslides'
# -rw-------  1 root root      175 Dec 16 22:11  Produce.gvid
# -rw-------  1 root root  4297055 Dec 28  2024  Produce.mp4
# -rw-------  1 root root      175 Nov  7 09:42 'PROJETS PRO.gdoc'
# -rw-------  1 root root      175 Dec 27 18:10  prompt_batch.gsheet
# -rw-------  1 root root      175 Dec 15  2022 'script video anglais.gdoc'
# -rw-------  1 root root      175 Jun 28  2025  séries.gdoc
# -rw-------  1 root root      175 Apr  7  2020 'sph .gdoc'
# -rw-------  1 root root      175 Mar 29  2021 'synthese centrale.gdoc'
# -rw-------  1 root root      175 Jun  6  2025 'Taff pro .gdoc'
# -rw-------  1 root root     1811 Jul  6 12:31  TAZER.txt
# -rw-------  1 root root  7726212 Jul  4 13:14  tazparoles.wav
# -rw-------  1 root root 82800118 Dec 25 17:42  TCL1.2.apk
# -rw-------  1 root root 82800118 Dec 25 17:46  TCL1.3.apk
# -rw-------  1 root root 82800118 Dec 25 17:57  TCL1.4.apk
# -rw-------  1 root root 82800118 Dec 25 18:06  TCL1.5.apk
# -rw-------  1 root root 82800118 Dec 25 18:08  TCL1.6.apk
# -rw-------  1 root root 82821295 Dec 25 21:18  TCL1.7.apk
# -rw-------  1 root root 82821295 Dec 25 21:25  TCL1.8.apk
# -rw-------  1 root root 82821295 Dec 25 21:32  TCL1.9.apk
# -rw-------  1 root root 82821295 Dec 25 21:37  TCL2.0.apk
# -rw-------  1 root root 82800118 Dec 25 17:08  TCL.apk
# -rw-------  1 root root      175 Jun 13  2024 'texte sspm.gdoc'
# -rw-------  1 root root      175 Jun  7  2022 'texte TIPE.gdoc'
# -rw-------  1 root root      175 Mar 26  2021 'tipe DONNEES.gdoc'
# -rw-------  1 root root      175 Jun 24  2025 'TP R.gdoc'
# -rw-------  1 root root   247791 Jun 24  2025 'TP R.pdf'
# -rw-------  1 root root      175 May 26  2024 'Trucs à faire maths .gdoc'
# total 826731
# -rw-------  1 root root  5844875 Jul  7 14:35 20250618_154133.jpg
# drwx------  2 root root     4096 Dec 15  2022 anglais proba
# -rw-------  1 root root      175 Jun  5  2025 appel guillaume gaudron.gdoc
# drwx------  2 root root     4096 Nov 22  2021 bleu
# drwx------  3 root root     4096 Jul  4  2024 Borderlands-Sensitivity-Changer-main
# -rw-------  1 root root      175 Nov 11 11:05 Bouquins.gdoc
# -rw-------  1 root root      175 Mar  2  2020 Ces idées qui collent.gslides
# -rw-------  1 root root      175 Mar 12  2021 chaine mentale tipe.gdoc
# -rw-------  1 root root      175 Feb 14  2024 Chapitre_9-1 (1).gdoc

# %%
ADAPTER_DIR = "/content/drive/.shortcut-targets-by-id/14ok9jUkxn5Ww4SgxFGRMgEXs78uQROae/steam_project_lora/steam_lora_adapter"

# %%
import os
print(os.path.isfile(os.path.join(ADAPTER_DIR, "adapter_config.json")))
print(os.path.isfile(os.path.join(ADAPTER_DIR, "adapter_model.safetensors")))
# Out:
# True
# True

# %%
# =========================
# STEAM LoRA BATCH GENERATION (ROBUST + RESUME + SAVE TO DRIVE)
# - Reads:  /content/prompt_batch.csv (already uploaded)
# - Loads adapter from: Drive shortcut targets (path below)
# - Writes output directly to Drive (so you won't lose progress if Colab resets)
# - Resumes automatically if the output file already exists
# =========================

# !pip -q install transformers accelerate bitsandbytes peft pandas

import os
import re
import csv
import pandas as pd
import torch

from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from peft import PeftModel
from google.colab import drive

# ---- 0) Mount Drive (required) ----
drive.mount("/content/drive")

# ---- 1) Paths ----
INPUT_CSV = "/content/prompt_batch.csv"

# Adapter path (from your find result)
ADAPTER_DIR = "/content/drive/.shortcut-targets-by-id/14ok9jUkxn5Ww4SgxFGRMgEXs78uQROae/steam_project_lora/steam_lora_adapter"

# Write directly to Drive (persistent)
OUTPUT_CSV = "/content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv"

# ---- 2) Generation settings (T4 safe) ----
BASE_MODEL = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"
MAX_NEW_TOKENS = 220
BATCH_SIZE = 4                 # if OOM -> set 2
SAVE_EVERY_N_BATCHES = 5       # flush every 5 batches (~20 rows)

# ---- 3) Sanity checks ----
assert os.path.isfile(INPUT_CSV), f"Missing INPUT_CSV: {INPUT_CSV}"
assert os.path.isfile(os.path.join(ADAPTER_DIR, "adapter_config.json")), "adapter_config.json not found in ADAPTER_DIR"
assert (
    os.path.isfile(os.path.join(ADAPTER_DIR, "adapter_model.safetensors"))
    or os.path.isfile(os.path.join(ADAPTER_DIR, "adapter_model.bin"))
), "adapter model weights not found (adapter_model.safetensors/bin)"

print("INPUT_CSV OK:", INPUT_CSV)
print("ADAPTER_DIR OK:", ADAPTER_DIR)
print("OUTPUT_CSV:", OUTPUT_CSV)

# Optional (recommended): copy adapter locally for speed/stability
LOCAL_ADAPTER = "/content/steam_lora_adapter"
if not os.path.isdir(LOCAL_ADAPTER):
    # !rm -rf /content/steam_lora_adapter
    # !cp -r "$ADAPTER_DIR" /content/steam_lora_adapter
ADAPTER_DIR = LOCAL_ADAPTER
print("Using local adapter dir:", ADAPTER_DIR)

# ---- 4) Load tokenizer/model + attach adapter ----
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_quant_type="nf4",
)

# Tokenizer from base model (safe)
tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL, use_fast=True)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    quantization_config=bnb_config,
    device_map="auto",
)

model = PeftModel.from_pretrained(base_model, ADAPTER_DIR)
model.eval()

def clean_generated(text: str) -> str:
    t = str(text).strip()
    t = re.sub(r"^\s*review\s*:\s*", "", t, flags=re.IGNORECASE)
    return t.strip()

@torch.inference_mode()
def generate_batch(prompts: list[str]) -> list[str]:
    enc = tokenizer(
        prompts,
        return_tensors="pt",
        padding=True,
        truncation=True,
        max_length=512,
    )
    enc = {k: v.to(model.device) for k, v in enc.items()}
    input_lens = enc["attention_mask"].sum(dim=1)

    out = model.generate(
        **enc,
        min_new_tokens=130,
        max_new_tokens=190,

        do_sample=True,
        temperature=0.75,
        top_p=0.9,
        repetition_penalty=1.15,
        no_repeat_ngram_size=3,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.pad_token_id,
        use_cache=True,
    )

    results = []
    for i in range(out.size(0)):
        gen_ids = out[i, input_lens[i]:]
        txt = tokenizer.decode(gen_ids, skip_special_tokens=True)
        results.append(clean_generated(txt))
    return results

# ---- 5) Load prompts + keep engineered ----
df = pd.read_csv(INPUT_CSV, engine="python")
df["method"] = df["method"].astype(str)
df["generated_text"] = df["generated_text"].fillna("").astype(str)

to_gen = df[df["method"] == "engineered"].copy().reset_index(drop=True)
print("Engineered rows to generate:", len(to_gen))

# ---- 6) Resume logic (if OUTPUT_CSV already exists on Drive) ----
start_idx = 0
if os.path.exists(OUTPUT_CSV):
    done = pd.read_csv(OUTPUT_CSV, engine="python")
    start_idx = len(done)
    print(f"Resuming: {start_idx} already generated, remaining: {len(to_gen) - start_idx}")
else:
    # Create empty output with header
    header_df = to_gen.iloc[0:0].copy()
    header_df["generated_text"] = ""
    header_df.to_csv(
        OUTPUT_CSV,
        index=False,
        encoding="utf-8",
        quoting=csv.QUOTE_ALL,
        lineterminator="\n",
    )
    print("Created output file:", OUTPUT_CSV)

# ---- 7) Streaming generation + periodic flush to Drive ----
rows_buffer = []
batch_counter = 0

for i in range(start_idx, len(to_gen), BATCH_SIZE):
    batch = to_gen.iloc[i:i+BATCH_SIZE].copy()
    prompts = batch["prompt"].tolist()

    gens = generate_batch(prompts)

    batch["generated_text"] = gens
    batch["method"] = "finetuned_v5"
    rows_buffer.append(batch)
    batch_counter += 1

    # Flush every N batches
    if batch_counter % SAVE_EVERY_N_BATCHES == 0:
        chunk = pd.concat(rows_buffer, ignore_index=True)
        chunk.to_csv(
            OUTPUT_CSV,
            mode="a",
            header=False,
            index=False,
            encoding="utf-8",
            quoting=csv.QUOTE_ALL,
            lineterminator="\n",
        )
        rows_buffer = []
        print(f"Saved progress: {min(i + BATCH_SIZE, len(to_gen))}/{len(to_gen)} rows -> {OUTPUT_CSV}")

# Flush remaining
if rows_buffer:
    chunk = pd.concat(rows_buffer, ignore_index=True)
    chunk.to_csv(
        OUTPUT_CSV,
        mode="a",
        header=False,
        index=False,
        encoding="utf-8",
        quoting=csv.QUOTE_ALL,
        lineterminator="\n",
    )

print("DONE. Output saved on Drive:", OUTPUT_CSV)

# ---- 8) Quick quality check ----
out = pd.read_csv(OUTPUT_CSV, engine="python")
wc = out["generated_text"].fillna("").str.split().str.len()
print("Output rows:", len(out))
print("Mean words:", float(wc.mean()))
print("Share 100-140:", float(((wc >= 100) & (wc <= 140)).mean()))
print("\nLast sample (first 350 chars):\n", out["generated_text"].iloc[-1][:350])
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 12.9 MB/s eta 0:00:00
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# INPUT_CSV OK: /content/prompt_batch.csv
# ADAPTER_DIR OK: /content/drive/.shortcut-targets-by-id/14ok9jUkxn5Ww4SgxFGRMgEXs78uQROae/steam_project_lora/steam_lora_adapter
# OUTPUT_CSV: /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Using local adapter dir: /content/steam_lora_adapter
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/551 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Engineered rows to generate: 4422
# Created output file: /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 20/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 40/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 60/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 80/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 100/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 120/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 140/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 160/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 180/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 200/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 220/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 240/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 260/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 280/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 300/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 320/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 340/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 360/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 380/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 400/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 420/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 440/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 460/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 480/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 500/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 520/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 540/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 560/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 580/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 600/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 620/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 640/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 660/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 680/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 700/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 720/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 740/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 760/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 780/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 800/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 820/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 840/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 860/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 880/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 900/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 920/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Saved progress: 940/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 960/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 980/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1000/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1020/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1040/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1060/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1080/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1100/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1120/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1140/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1160/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1180/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1200/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1220/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1240/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1260/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1280/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1300/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1320/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1340/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1360/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1380/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1400/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1420/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1440/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1460/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1480/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1500/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1520/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1540/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1560/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1580/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1600/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1620/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1640/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Saved progress: 1660/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1680/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1700/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1720/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1740/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1760/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1780/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1800/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1820/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1840/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1860/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1880/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1900/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1920/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1940/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1960/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 1980/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2000/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2020/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2040/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2060/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2080/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2100/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2120/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2140/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2160/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2180/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2200/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2220/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2240/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2260/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2280/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2300/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2320/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2340/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2360/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2380/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2400/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2420/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2440/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2460/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2480/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2500/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2520/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2540/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2560/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2580/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2600/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2620/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2640/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2660/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2680/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2700/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2720/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2740/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2760/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2780/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2800/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2820/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2840/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2860/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2880/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2900/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2920/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2940/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2960/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 2980/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3000/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3020/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3040/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3060/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3080/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3100/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3120/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3140/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3160/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3180/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3200/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3220/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3240/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3260/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3280/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3300/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3320/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3340/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3360/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3380/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3400/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3420/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3440/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Saved progress: 3460/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3480/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3500/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3520/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3540/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3560/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3580/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3600/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3620/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3640/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3660/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3680/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3700/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
# Saved progress: 3720/4422 rows -> /content/drive/MyDrive/steam_project_lora/prompt_batch_finetuned_v6_long.csv
